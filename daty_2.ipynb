# %%
STUDENT={"NAME":"VIJI","AGE":90,"DEP":"CSE"}
print(STUDENT)
student_marks{
    "anu":60,
    "viji":75,
    "ruthran":80,
    "nithiya":90,
    "dhatchana":95,
    "priya":80
}
average_marks=sum(student_marks.values)
# Out:
# {'NAME': 'VIJI', 'AGE': 90, 'DEP': 'CSE'}
